# %%
# encoding:utf-8
import requests 

# client_id 为官网获取的AK， client_secret 为官网获取的SK
host = 'https://aip.baidubce.com/oauth/2.0/token?grant_type=client_credentials&client_id=GxTa6eyXMu5OL6aVWvM6C1nU&client_secret=aLpG3DOr3ct6Va8SyGD8mBG4yXvdAZFa'
response = requests.get(host)
if response:
    print(response.json())
# Out:
# {'refresh_token': '25.13172e18f32a865df14f6b20a3c47a9a.315360000.1892296301.282335-18081489', 'expires_in': 2592000, 'session_key': '9mzdC3t9AmxZopboNikIwV85gmGikB1raWSorSxYo2TxlvlY17wvQFMzjSjwbB3DyxzhVoNbmF0bS6RokBLOrG+xqHQxyw==', 'access_token': '24.0c7b29573b3f584a0f9fb8c1fc1e9cbd.2592000.1579528301.282335-18081489', 'scope': 'public brain_all_scope brain_colourize brain_stretch_restore brain_dehaze brain_contrast_enhance brain_image_quality_enhance wise_adapt lebo_resource_base lightservice_public hetu_basic lightcms_map_poi kaidian_kaidian ApsMisTest_Test权限 vis-classify_flower lpq_开放 cop_helloScope ApsMis_fangdi_permission smartapp_snsapi_base iop_autocar oauth_tp_app smartapp_smart_game_openapi oauth_sessionkey smartapp_swanid_verify smartapp_opensource_openapi smartapp_opensource_recapi fake_face_detect_开放Scope vis-ocr_虚拟人物助理 idl-video_虚拟人物助理', 'session_secret': '52867a4f6b3bdc35325273cd2ae4655a'}

# %%
# encoding:utf-8

import requests
import base64

'''
图像对比度增强
'''

request_url = "https://aip.baidubce.com/rest/2.0/image-process/v1/contrast_enhance"
# 二进制方式打开图片文件
f = open('b.jpg', 'rb')
img = base64.b64encode(f.read())

params = {"image":img}
access_token = '24.0c7b29573b3f584a0f9fb8c1fc1e9cbd.2592000.1579528301.282335-18081489'
request_url = request_url + "?access_token=" + access_token
headers = {'content-type': 'application/x-www-form-urlencoded'}
response = requests.post(request_url, data=params, headers=headers)
if response:
    print (response.json())
# Out:
# {'log_id': 4977876116678184021, 'image': '...'}
